# %% [markdown]
# **My Markdown header**
#
#  Hello this is my test_notebook for peer grade assignment

# %% [markdown]
# Data science involves a variety of programming languages that help with data analysis, visualization, and machine learning.
# Here are some of the most commonly used ones:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# Data scientists often use various libraries to perform tasks such as data analysis, visualization, and machine learning.
# Here are some of the most popular data science libraries:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. TensorFlow
# 7. PyTorch

# %% [markdown]
# Data scientists use a wide range of tools for data processing, analysis, visualization, and machine learning.
# The table below lists some of the most commonly used tools in Data Science:
#
# | Category           | Tool Name         | Description |
# |--------------------|------------------|--------------|
# | Data Analysis       | Python, R         | Programming languages for data manipulation and analysis |
# | Data Visualization  | Tableau, Power BI, Matplotlib | Tools and libraries for creating data visualizations |
# | Machine Learning    | Scikit-learn, TensorFlow, PyTorch | Libraries and frameworks for building predictive models |
# | Big Data Processing | Apache Spark, Hadoop | Tools for handling large-scale data processing |
# | Data Storage        | MySQL, PostgreSQL, MongoDB | Databases for storing and managing structured/unstructured data |

# %% [markdown]
# Arithmetic expressions are used in programming and mathematics to perform basic calculations such as addition, subtraction, multiplication, and division.
# Here are some examples of arithmetic expressions:
#
# 1. `5 + 3` → Addition
# 2. `10 - 4` → Subtraction
# 3. `6 * 7` → Multiplication
# 4. `20 / 5` → Division
# 5. `10 % 3` → Modulus (remainder after division)
# 6. `(4 + 3) * 2` → Using parentheses to control order of operations

# %%
# This code multiplies and adds numbers

# Define numbers
a = 5
b = 3
c = 2

# Perform arithmetic operations
# multiplication_result = a * b
# addition_result = a + c

# Display the results
print(a * b)
print(a + c)

# %%
a = 5
b = 3
c = 2

# %%
print(a * b)
print(a + c)

# %%
# This code converts minutes to hours

# Define the number of minutes
minutes = 150

# Convert minutes to hours
hours = minutes / 60

# Display the result
print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# Data science projects typically involve several key steps to ensure accurate and meaningful insights.
# Here are the main stages of a typical data science workflow:
#
# - Data Collection
# - Data Cleaning
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Model Building
# - Model Evaluation
# - Deployment and Monitoring

# %% [markdown]
# **Author:** Pongsakorn Sakulpruek
# **Date:** October 22, 2025
# **Project:** Data Science Fundamentals
